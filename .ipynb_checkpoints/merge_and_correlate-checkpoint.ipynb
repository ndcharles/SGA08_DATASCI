# %% [markdown]
# # Merging two NBA datasets (nba list and salaries)

# %%
import pandas as pd

# %%
players = pd.read_csv('players.csv')
salary = pd.read_csv('salaries_1985to2018.csv')

# %%
players.info()
print()
print()
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4685 entries, 0 to 4684
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _id          4685 non-null   object
#  1   birthDate    4657 non-null   object
#  2   birthPlace   4185 non-null   object
#  3   career_AST   4685 non-null   float64
#  4   career_FG%   4685 non-null   object
#  5   career_FG3%  3557 non-null   object
#  6   career_FT%   4685 non-null   object
#  7   career_G     4685 non-null   int64
#  8   career_PER   4685 non-null   object
#  9   career_PTS   4685 non-null   float64
#  10  career_TRB   4685 non-null   object
#  11  career_WS    4685 non-null   object
#  12  career_eFG%  3557 non-null   object
#  13  college      4372 non-null   object
#  14  draft_pick   3369 non-null   object
#  15  draft_round  3507 non-null   object
#  16  draft_team   3507 non-null   object
#  17  draft_year   3306 non-null   object
# ...

# %%
players.head()
# Out:
#          _id         birthDate              birthPlace  career_AST career_FG%  \
# 0  abdelal01     June 24, 1968            Cairo, Egypt         0.3       50.2
# 1  abdulza01     April 7, 1946      Brooklyn, New York         1.2       42.8
# 2  abdulka01    April 16, 1947      New York, New York         3.6       55.9
# 3  abdulma02     March 9, 1969   Gulfport, Mississippi         3.5       44.2
# 4  abdulta01  November 3, 1974  Maisons Alfort, France         1.1       41.7
#
#   career_FG3% career_FT%  career_G career_PER  career_PTS  ...    draft_pick  \
# 0         0.0       70.1       256       13.0         5.7  ...  25th overall
# 1         NaN       72.8       505       15.1         9.0  ...   5th overall
# 2         5.6       72.1      1560       24.6        24.6  ...   1st overall
# 3        35.4       90.5       586       15.4        14.6  ...   3rd overall
# 4        23.7       70.3       236       11.4         7.8  ...  11th overall
#
# ...

# %%
players.columns
# Out:
# Index(['_id', 'birthDate', 'birthPlace', 'career_AST', 'career_FG%',
#        'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS',
#        'career_TRB', 'career_WS', 'career_eFG%', 'college', 'draft_pick',
#        'draft_round', 'draft_team', 'draft_year', 'height', 'highSchool',
#        'name', 'position', 'shoots', 'weight'],
#       dtype='object')

# %%
players.drop(['career_AST', 'career_FG%', 'career_FG3%', 'career_FT%', 'career_G', 'career_PER', 'career_PTS', 'career_TRB', 'career_WS', 'career_eFG%', 'draft_round'], inplace=True, axis=1)

# %%
players.columns
# Out:
# Index(['_id', 'birthDate', 'birthPlace', 'college', 'draft_pick', 'draft_team',
#        'draft_year', 'height', 'highSchool', 'name', 'position', 'shoots',
#        'weight'],
#       dtype='object')

# %%
players.head()
# Out:
#          _id         birthDate              birthPlace  \
# 0  abdelal01     June 24, 1968            Cairo, Egypt
# 1  abdulza01     April 7, 1946      Brooklyn, New York
# 2  abdulka01    April 16, 1947      New York, New York
# 3  abdulma02     March 9, 1969   Gulfport, Mississippi
# 4  abdulta01  November 3, 1974  Maisons Alfort, France
#
#                                              college    draft_pick  \
# 0                                    Duke University  25th overall
# 1                              Iowa State University   5th overall
# 2              University of California, Los Angeles   1st overall
# 3                         Louisiana State University   3rd overall
# 4  University of Michigan, San Jose State University  11th overall
#
#                draft_team draft_year height  \
# 0  Portland Trail Blazers       1990   6-10
# 1       Cincinnati Royals       1968    6-9
# 2         Milwaukee Bucks       1969    7-2
# 3          Denver Nuggets       1990    6-1
# ...

# %%
salary.columns
# Out:
# Index(['league', 'player_id', 'salary', 'season', 'season_end', 'season_start',
#        'team'],
#       dtype='object')

# %%
salary.head()
# Out:
#   league  player_id  salary   season  season_end  season_start  \
# 0    NBA  abdelal01  395000  1990-91        1991          1990
# 1    NBA  abdelal01  494000  1991-92        1992          1991
# 2    NBA  abdelal01  500000  1992-93        1993          1992
# 3    NBA  abdelal01  805000  1993-94        1994          1993
# 4    NBA  abdelal01  650000  1994-95        1995          1994
#
#                      team
# 0  Portland Trail Blazers
# 1  Portland Trail Blazers
# 2          Boston Celtics
# 3          Boston Celtics
# 4        Sacramento Kings

# %%
players_merged = players.merge(salary, left_on='_id', right_on='player_id')

# %%
players_merged.head()
# Out:
#          _id      birthDate    birthPlace          college    draft_pick  \
# 0  abdelal01  June 24, 1968  Cairo, Egypt  Duke University  25th overall
# 1  abdelal01  June 24, 1968  Cairo, Egypt  Duke University  25th overall
# 2  abdelal01  June 24, 1968  Cairo, Egypt  Duke University  25th overall
# 3  abdelal01  June 24, 1968  Cairo, Egypt  Duke University  25th overall
# 4  abdelal01  June 24, 1968  Cairo, Egypt  Duke University  25th overall
#
#                draft_team draft_year height  \
# 0  Portland Trail Blazers       1990   6-10
# 1  Portland Trail Blazers       1990   6-10
# 2  Portland Trail Blazers       1990   6-10
# 3  Portland Trail Blazers       1990   6-10
# 4  Portland Trail Blazers       1990   6-10
#
#                              highSchool            name       position shoots  \
# 0  Bloomfield in Bloomfield, New Jersey  Alaa Abdelnaby  Power Forward  Right
# 1  Bloomfield in Bloomfield, New Jersey  Alaa Abdelnaby  Power Forward  Right
# ...

# %%
players_merged.corr()
# Out:
#                 salary  season_end  season_start
# salary        1.000000    0.356966      0.356966
# season_end    0.356966    1.000000      1.000000
# season_start  0.356966    1.000000      1.000000

# %% [markdown]
# # Correlating NBA dataset

# %%
NBA = pd.read_csv('nba.csv')

# %%
NBA.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
NBA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
NBA.dropna(inplace=True)

# %%
NBA.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 3  Georgia State  1148640.0
# 6            LSU  1170960.0
# 7        Gonzaga  2165160.0

# %%
# to convert positions to integer values
NBA['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
# create a dictionary of key pairs
Position = {'PG': 1, 'SF': 2, 'SG': 3, 'PF': 4, 'C': 5}
NBA.Position = [Position[item] for item in NBA.Position]
print(Position)
# Out:
# {'PG': 1, 'SF': 2, 'SG': 3, 'PF': 4, 'C': 5}

# %%
NBA.head(15)
# Out:
#                        Name            Team  Number  Position   Age Height  \
# 0             Avery Bradley  Boston Celtics     0.0         1  25.0    6-2
# 1               Jae Crowder  Boston Celtics    99.0         2  25.0    6-6
# 3               R.J. Hunter  Boston Celtics    28.0         3  22.0    6-5
# 6             Jordan Mickey  Boston Celtics    55.0         4  21.0    6-8
# 7              Kelly Olynyk  Boston Celtics    41.0         5  25.0    7-0
# 8              Terry Rozier  Boston Celtics    12.0         1  22.0    6-2
# 9              Marcus Smart  Boston Celtics    36.0         1  22.0    6-4
# 10          Jared Sullinger  Boston Celtics     7.0         5  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0         1  27.0    5-9
# 12              Evan Turner  Boston Celtics    11.0         3  27.0    6-7
# 13              James Young  Boston Celtics    13.0         3  20.0    6-6
# ...

# %%
NBA.corr(method='pearson')
# Out:
#             Number  Position       Age    Weight    Salary
# Number    1.000000  0.238068  0.025090  0.239768 -0.154655
# Position  0.238068  1.000000  0.000038  0.765091  0.022519
# Age       0.025090  0.000038  1.000000  0.058737  0.159385
# Weight    0.239768  0.765091  0.058737  1.000000  0.144334
# Salary   -0.154655  0.022519  0.159385  0.144334  1.000000

# %%
NBA.corr(method='spearman')
# Out:
#             Number  Position       Age    Weight    Salary
# Number    1.000000  0.263006 -0.010258  0.243323 -0.146818
# Position  0.263006  1.000000 -0.002230  0.765667  0.022403
# Age      -0.010258 -0.002230  1.000000  0.064902  0.235912
# Weight    0.243323  0.765667  0.064902  1.000000  0.130848
# Salary   -0.146818  0.022403  0.235912  0.130848  1.000000

# %% [markdown]
# Position and weight are highly correlated (pearson coeff = 0.76; spearman coeff = 0.7).
